# %% [markdown]
# # CIFAR-10 dataset classification with MLPs
#
# Author: Tanwi Mallick, adapting codes from Bethany Lusch, Prasanna Balprakash, Corey Adams, and Kyle Felker
#
# In this notebook, we'll continue the CIFAR-10 problem but using the Keras API (as included in the TensorFlow library)
#
# First, the needed imports.

# %%
# %matplotlib inline

import tensorflow as tf

import numpy
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ## CIFAR-10 data set
#
# Again we'll load the cifar10 data set. CIFAR-10 dataset contains 32x32 color images from 10 classes: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck. If you haven't downloaded it already, it could take a while.
#
# <img src="https://github.com/UkamakaNnyaba/ai-science-training-series/blob/main/03_neural_networks_tensorflow/images/CIFAR-10.png?raw=1"  align="left"/>

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train = x_train.astype(numpy.float32)
x_test  = x_test.astype(numpy.float32)

x_train /= 255.
x_test  /= 255.

y_train = y_train.astype(numpy.int32)
y_test  = y_test.astype(numpy.int32)

print()
print('CIFAR-10 data loaded: train:',len(x_train),'test:',len(x_test))
print('X_train:', x_train.shape)
print('y_train:', y_train.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step
#
# CIFAR-10 data loaded: train: 50000 test: 10000
# X_train: (50000, 32, 32, 3)
# y_train: (50000, 1)

# %% [markdown]
# ### Download the dataset and load

# %%
# !pip install image-dataset-loader
# !wget https://s3.amazonaws.com/fast-ai-imageclas/cifar10.tgz
# !tar -xf cifar10.tgz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting image-dataset-loader
#   Downloading image_dataset_loader-0.0.0-py3-none-any.whl (4.3 kB)
# Requirement already satisfied: imageio>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from image-dataset-loader) (2.9.0)
# Requirement already satisfied: numpy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from image-dataset-loader) (1.21.6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio>=2.0.0->image-dataset-loader) (7.1.2)
# Installing collected packages: image-dataset-loader
# Successfully installed image-dataset-loader-0.0.0
# --2022-10-30 20:10:43--  https://s3.amazonaws.com/fast-ai-imageclas/cifar10.tgz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.129.24
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.129.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 135107811 (129M) [application/x-tar]
# Saving to: ‘cifar10.tgz’
#
# cifar10.tgz         100%[===================>] 128.85M  66.8MB/s    in 1.9s
#
# 2022-10-30 20:10:45 (66.8 MB/s) - ‘cifar10.tgz’ saved [135107811/135107811]

# %%
from image_dataset_loader import load
(x_train, y_train), (x_test, y_test) = load('cifar10', ['train', 'test'])

x_train = x_train.astype(numpy.float32)
x_test  = x_test.astype(numpy.float32)

x_train /= 255.
x_test  /= 255.

y_train = y_train.astype(numpy.int32)
y_test  = y_test.astype(numpy.int32)

print()
print('CIFAR-10 data loaded: train:',len(x_train),'test:',len(x_test))
print('X_train:', x_train.shape)
print('y_train:', y_train.shape)
# Out:
# CIFAR-10 data loaded: train: 50000 test: 10000
# X_train: (50000, 32, 32, 3)
# y_train: (50000,)

# %% [markdown]
# This time we won't flatten the images upfront.
#
# The training data (`X_train`) is a 3rd-order tensor of size (50000, 32, 32), i.e. it consists of 50000 images of size 32x32 pixels.
#
# `y_train` is a 50000-dimensional vector containing the correct classes ('airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck') for each training sample.

# %% [markdown]
# <img src="https://github.com/UkamakaNnyaba/ai-science-training-series/blob/main/03_neural_networks_tensorflow/images/image_representation.png?raw=1"  align="left"/>

# %% [markdown]
# ## Linear model
#
# ### Initialization
#
# Let's begin with a simple linear model, but with the Keras library. First we use a `Flatten` layer to convert image data into vectors.
#
# A `Dense()` layer is a basic layer: $xW + b$ with an optional nonlinearity applied ("activation function"). The `Dense` layer connects each input to each output with some weight parameter. They are also called "fully connected."
#
# Here we add a `Dense` layer that has $32\times32\times3=3072$ input nodes (one for each pixel in the input image) and 10 output nodes.

# %%
class LinearClassifier(tf.keras.models.Model):

    def __init__(self, activation=tf.nn.tanh):
        tf.keras.models.Model.__init__(self)

        self.layer_1 = tf.keras.layers.Dense(10, activation='softmax')


    def call(self, inputs):

        x = tf.keras.layers.Flatten()(inputs)
        x = self.layer_1(x)

        return x

# %% [markdown]
# We select *sparse categorical crossentropy* as the loss function, select [*stochastic gradient descent*](https://keras.io/optimizers/#sgd) as the optimizer, add *accuracy* to the list of metrics to be evaluated, and `compile()` the model. Note there are [several different options](https://keras.io/optimizers/) for the optimizer in Keras that we could use instead of *sgd*.

# %%
linear_model = LinearClassifier()

linear_model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd", metrics=['accuracy'])

# %% [markdown]
# ### Learning

# %% [markdown]
# Now we are ready to train our first model. An epoch means one pass through the whole training data.

# %% [markdown]
# Here is a concise way to train the network. The fit function handles looping over the batches. We'll see a more verbose approach in the next notebook that allows more performance tuning.

# %% [markdown]
# You can run the code below multiple times and it will continue the training process from where it left off. If you want to start from scratch, re-initialize the model using the code a few cells ago.

# %%
# %%time
# This took about a third of a second per epoch on my laptop
batch_size = 512
epochs = 30
history = linear_model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=2)
# Out:
# Epoch 1/30
# 98/98 - 2s - loss: 2.1341 - accuracy: 0.2337 - 2s/epoch - 17ms/step
# Epoch 2/30
# 98/98 - 1s - loss: 1.9838 - accuracy: 0.3035 - 1s/epoch - 11ms/step
# Epoch 3/30
# 98/98 - 1s - loss: 1.9306 - accuracy: 0.3270 - 1s/epoch - 10ms/step
# Epoch 4/30
# 98/98 - 1s - loss: 1.8996 - accuracy: 0.3419 - 1s/epoch - 11ms/step
# Epoch 5/30
# 98/98 - 1s - loss: 1.8773 - accuracy: 0.3521 - 1s/epoch - 11ms/step
# Epoch 6/30
# 98/98 - 1s - loss: 1.8616 - accuracy: 0.3553 - 1s/epoch - 11ms/step
# Epoch 7/30
# 98/98 - 1s - loss: 1.8488 - accuracy: 0.3618 - 1s/epoch - 10ms/step
# Epoch 8/30
# 98/98 - 1s - loss: 1.8384 - accuracy: 0.3660 - 1s/epoch - 11ms/step
# Epoch 9/30
# 98/98 - 1s - loss: 1.8300 - accuracy: 0.3701 - 1s/epoch - 10ms/step
# Epoch 10/30
# 98/98 - 1s - loss: 1.8216 - accuracy: 0.3722 - 1s/epoch - 10ms/step
# Epoch 11/30
# 98/98 - 1s - loss: 1.8157 - accuracy: 0.3749 - 987ms/epoch - 10ms/step
# Epoch 12/30
# 98/98 - 1s - loss: 1.8091 - accuracy: 0.3780 - 1s/epoch - 10ms/step
# Epoch 13/30
# 98/98 - 1s - loss: 1.8052 - accuracy: 0.3791 - 990ms/epoch - 10ms/step
# Epoch 14/30
# 98/98 - 1s - loss: 1.8001 - accuracy: 0.3823 - 998ms/epoch - 10ms/step
# Epoch 15/30
# 98/98 - 1s - loss: 1.7953 - accuracy: 0.3841 - 1s/epoch - 10ms/step
# Epoch 16/30
# 98/98 - 1s - loss: 1.7920 - accuracy: 0.3845 - 1s/epoch - 10ms/step
# Epoch 17/30
# 98/98 - 1s - loss: 1.7877 - accuracy: 0.3851 - 1s/epoch - 10ms/step
# Epoch 18/30
# 98/98 - 1s - loss: 1.7850 - accuracy: 0.3867 - 1s/epoch - 10ms/step
# Epoch 19/30
# 98/98 - 1s - loss: 1.7815 - accuracy: 0.3897 - 1s/epoch - 10ms/step
# Epoch 20/30
# 98/98 - 1s - loss: 1.7785 - accuracy: 0.3900 - 1s/epoch - 10ms/step
# Epoch 21/30
# 98/98 - 1s - loss: 1.7758 - accuracy: 0.3899 - 1s/epoch - 10ms/step
# Epoch 22/30
# 98/98 - 1s - loss: 1.7737 - accuracy: 0.3923 - 1s/epoch - 10ms/step
# Epoch 23/30
# 98/98 - 1s - loss: 1.7703 - accuracy: 0.3931 - 1s/epoch - 10ms/step
# Epoch 24/30
# 98/98 - 1s - loss: 1.7678 - accuracy: 0.3952 - 1s/epoch - 10ms/step
# Epoch 25/30
# 98/98 - 1s - loss: 1.7652 - accuracy: 0.3950 - 1s/epoch - 10ms/step
# Epoch 26/30
# 98/98 - 1s - loss: 1.7643 - accuracy: 0.3948 - 1s/epoch - 10ms/step
# Epoch 27/30
# 98/98 - 1s - loss: 1.7620 - accuracy: 0.3967 - 1000ms/epoch - 10ms/step
# Epoch 28/30
# 98/98 - 1s - loss: 1.7598 - accuracy: 0.3984 - 1s/epoch - 10ms/step
# Epoch 29/30
# 98/98 - 1s - loss: 1.7579 - accuracy: 0.3981 - 997ms/epoch - 10ms/step
# Epoch 30/30
# 98/98 - 1s - loss: 1.7557 - accuracy: 0.3991 - 1000ms/epoch - 10ms/step
# CPU times: user 49.9 s, sys: 2.3 s, total: 52.2 s
# Wall time: 31.5 s

# %%
print(linear_model.summary())
# Out:
# Model: "linear_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               multiple                  30730
#
# =================================================================
# Total params: 30,730
# Trainable params: 30,730
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# The summary shows that there are 30730 parameters in our model, as the weight matrix is of size 3072x10, plus there's a bias vector of 10x1.

# %% [markdown]
# Let's now see how the training progressed.
#
# * *Loss* is a function of the difference of the network output and the target values.  We are minimizing the loss function during training so it should decrease over time.
# * *Accuracy* is the classification accuracy for the training data (100*accuracy is the percentage labeled correctly), so it should increase over time
#
# Note that for either measure, we cannot fully trust the progress, as the model may have overfitted and just memorized the training data.

# %%
plt.figure(figsize=(5,3))
plt.plot(history.epoch,history.history['loss'])
plt.title('loss')

plt.figure(figsize=(5,3))
plt.plot(history.epoch,history.history['accuracy'])
plt.title('accuracy');

# %% [markdown]
# ### Inference
#
# For a better measure of the quality of the model, let's see the model accuracy for the test data.

# %%
linscores = linear_model.evaluate(x_test, y_test, verbose=2)
print("%s: %.2f%%" % (linear_model.metrics_names[1], linscores[1]*100))
# Out:
# 313/313 - 1s - loss: 1.7674 - accuracy: 0.3910 - 615ms/epoch - 2ms/step
# accuracy: 39.10%

# %% [markdown]
# We can now take a closer look on the results.
#
# Let's define a helper function to show the failure cases of our classifier.

# %%
def show_failures(predictions, trueclass=None, predictedclass=None, maxtoshow=20):
    rounded = numpy.argmax(predictions, axis=1)
    errors = rounded!=y_test.flatten()
    print('Showing max', maxtoshow, 'first failures. '
          'The predicted class is shown first and the correct class in parenthesis.')
    ii = 0
    plt.figure(figsize=(maxtoshow, 1))
    for i in range(x_test.shape[0]):
        if ii>=maxtoshow:
            break
        if errors[i]:
            if trueclass is not None and y_test[i] != trueclass:
                continue
            if predictedclass is not None and rounded[i] != predictedclass:
                continue
            plt.subplot(1, maxtoshow, ii+1)
            plt.axis('off')
            plt.imshow(x_test[i,:,:], cmap="gray")
            plt.title("%d (%d)" % (rounded[i], y_test[i]))
            ii = ii + 1

# %% [markdown]
# Here are the first 20 test images the linear model classified to a wrong class:

# %%
linpredictions = linear_model.predict(x_test)

show_failures(linpredictions)
# Out:
# 313/313 [==============================] - 1s 2ms/step
# Showing max 20 first failures. The predicted class is shown first and the correct class in parenthesis.

# %% [markdown]
# ## Multi-layer perceptron (MLP) network
#
# ### Initialization
#
# Let's now create a more complex MLP model that has multiple layers, non-linear activation functions, and dropout layers.
#
# `Dropout()` randomly sets a fraction of inputs to zero during training, which is one approach to regularization and can sometimes help to prevent overfitting.
#
# There are two options below, a simple and a bit more complex model.  Select either one.
#
# The output of the last layer needs to be a softmaxed 10-dimensional vector to match the groundtruth (`y_train`).

# %%
class NonlinearClassifier(tf.keras.models.Model):

    def __init__(self, activation=tf.nn.tanh):
        tf.keras.models.Model.__init__(self)

        self.layer_1 = tf.keras.layers.Dense(50, activation='relu')
        
        # A bit more complex model: (need to uncomment in call fn as well)
        self.layer_2 = tf.keras.layers.Dense(50, activation='relu')
        self.drop_3 = tf.keras.layers.Dropout(0.2)
        self.layer_4 = tf.keras.layers.Dense(50, activation='relu')
        self.drop_5 = tf.keras.layers.Dropout(0.2)
        more
        # The last layer needs to be like this:
        self.layer_out = tf.keras.layers.Dense(10, activation='softmax')


    def call(self, inputs):

        x = tf.keras.layers.Flatten()(inputs)
        x = self.layer_1(x)
        
        # The more complex version:
        x = self.layer_2(x)
        x = self.drop_3(x)
        x = self.layer_4(x)
        x = self.drop_5(x)
        
        x = self.layer_out(x)

        return x

# %% [markdown]
# Finally, we again `compile()` the model, this time using [*SGD*](https://keras.io/optimizers/#rmsprop) as the optimizer.

# %%
nonlinear_model = NonlinearClassifier()

nonlinear_model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd", metrics=['accuracy'])

# %% [markdown]
# ### Learning

# %%
# %%time
# This took around a third of a second per epoch on my laptop for the simpler version, 
# and around 1 second per epoch for the more complex one.
batch_size = 512
epochs = 30
history = nonlinear_model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=2)
# Out:
# Epoch 1/30
# 98/98 - 2s - loss: 2.2693 - accuracy: 0.1386 - 2s/epoch - 22ms/step
# Epoch 2/30
# 98/98 - 2s - loss: 2.2071 - accuracy: 0.1751 - 2s/epoch - 17ms/step
# Epoch 3/30
# 98/98 - 2s - loss: 2.1558 - accuracy: 0.2029 - 2s/epoch - 16ms/step
# Epoch 4/30
# 98/98 - 2s - loss: 2.1109 - accuracy: 0.2224 - 2s/epoch - 17ms/step
# Epoch 5/30
# 98/98 - 2s - loss: 2.0694 - accuracy: 0.2375 - 2s/epoch - 16ms/step
# Epoch 6/30
# 98/98 - 2s - loss: 2.0349 - accuracy: 0.2509 - 2s/epoch - 17ms/step
# Epoch 7/30
# 98/98 - 2s - loss: 2.0106 - accuracy: 0.2640 - 2s/epoch - 17ms/step
# Epoch 8/30
# 98/98 - 2s - loss: 1.9820 - accuracy: 0.2748 - 2s/epoch - 17ms/step
# Epoch 9/30
# 98/98 - 2s - loss: 1.9675 - accuracy: 0.2811 - 2s/epoch - 17ms/step
# Epoch 10/30
# 98/98 - 2s - loss: 1.9485 - accuracy: 0.2911 - 2s/epoch - 17ms/step
# Epoch 11/30
# 98/98 - 2s - loss: 1.9373 - accuracy: 0.2924 - 2s/epoch - 17ms/step
# Epoch 12/30
# 98/98 - 2s - loss: 1.9201 - accuracy: 0.2997 - 2s/epoch - 17ms/step
# Epoch 13/30
# 98/98 - 2s - loss: 1.9079 - accuracy: 0.3052 - 2s/epoch - 17ms/step
# Epoch 14/30
# 98/98 - 2s - loss: 1.8954 - accuracy: 0.3114 - 2s/epoch - 17ms/step
# Epoch 15/30
# 98/98 - 2s - loss: 1.8827 - accuracy: 0.3184 - 2s/epoch - 17ms/step
# Epoch 16/30
# 98/98 - 2s - loss: 1.8746 - accuracy: 0.3211 - 2s/epoch - 17ms/step
# Epoch 17/30
# 98/98 - 2s - loss: 1.8660 - accuracy: 0.3262 - 2s/epoch - 16ms/step
# Epoch 18/30
# 98/98 - 2s - loss: 1.8540 - accuracy: 0.3310 - 2s/epoch - 17ms/step
# Epoch 19/30
# 98/98 - 2s - loss: 1.8482 - accuracy: 0.3335 - 2s/epoch - 17ms/step
# Epoch 20/30
# 98/98 - 2s - loss: 1.8357 - accuracy: 0.3387 - 2s/epoch - 17ms/step
# Epoch 21/30
# 98/98 - 2s - loss: 1.8273 - accuracy: 0.3428 - 2s/epoch - 16ms/step
# Epoch 22/30
# 98/98 - 2s - loss: 1.8229 - accuracy: 0.3426 - 2s/epoch - 17ms/step
# Epoch 23/30
# 98/98 - 2s - loss: 1.8162 - accuracy: 0.3464 - 2s/epoch - 17ms/step
# Epoch 24/30
# 98/98 - 2s - loss: 1.8063 - accuracy: 0.3495 - 2s/epoch - 17ms/step
# Epoch 25/30
# 98/98 - 2s - loss: 1.8007 - accuracy: 0.3527 - 2s/epoch - 17ms/step
# Epoch 26/30
# 98/98 - 2s - loss: 1.7935 - accuracy: 0.3561 - 2s/epoch - 17ms/step
# Epoch 27/30
# 98/98 - 2s - loss: 1.7868 - accuracy: 0.3555 - 2s/epoch - 17ms/step
# Epoch 28/30
# 98/98 - 2s - loss: 1.7793 - accuracy: 0.3591 - 2s/epoch - 17ms/step
# Epoch 29/30
# 98/98 - 2s - loss: 1.7729 - accuracy: 0.3618 - 2s/epoch - 17ms/step
# Epoch 30/30
# 98/98 - 2s - loss: 1.7687 - accuracy: 0.3635 - 2s/epoch - 16ms/step
# CPU times: user 1min 22s, sys: 2.82 s, total: 1min 25s
# Wall time: 49.7 s

# %%
plt.figure(figsize=(5,3))
plt.plot(history.epoch,history.history['loss'])
plt.title('loss')

plt.figure(figsize=(5,3))
plt.plot(history.epoch,history.history['accuracy'])
plt.title('accuracy');

# %% [markdown]
# ### Inference
#
# Accuracy for test data.  The model should be better than the linear model.

# %%
# %%time
scores = nonlinear_model.evaluate(x_test, y_test, verbose=2)
print("%s: %.2f%%" % (nonlinear_model.metrics_names[1], scores[1]*100))
# Out:
# 313/313 - 1s - loss: 1.6928 - accuracy: 0.4051 - 717ms/epoch - 2ms/step
# accuracy: 40.51%
# CPU times: user 901 ms, sys: 49 ms, total: 950 ms
# Wall time: 773 ms

# %% [markdown]
# We can again take a closer look on the results, using the `show_failures()` function defined earlier.
#
# Here are the first 20 test images the MLP classified to a wrong class:

# %%
predictions = nonlinear_model.predict(x_test)

show_failures(predictions)
# Out:
# 313/313 [==============================] - 1s 2ms/step
# Showing max 20 first failures. The predicted class is shown first and the correct class in parenthesis.

# %% [markdown]
# We can use `show_failures()` to inspect failures in more detail. For example, here are failures in which the true class was "6":

# %%
show_failures(predictions, trueclass=6)
# Out:
# Showing max 20 first failures. The predicted class is shown first and the correct class in parenthesis.

# %% [markdown]
# We can also compute the confusion matrix to see which image get mixed the most, and look at classification accuracies separately for each class:

# %%
from sklearn.metrics import confusion_matrix

print('Confusion matrix (rows: true classes; columns: predicted classes):'); print()
cm=confusion_matrix(y_test, numpy.argmax(predictions, axis=1), labels=list(range(10)))
print(cm); print()

print('Classification accuracy for each class:'); print()
for i,j in enumerate(cm.diagonal()/cm.sum(axis=1)): print("%d: %.4f" % (i,j))
# Out:
# Confusion matrix (rows: true classes; columns: predicted classes):
#
# [[461  28  67  47  20  29  28  80 185  55]
#  [ 67 473   6  51  13  44  45  49  89 163]
#  [115  21 193  58 177 103 197 103  22  11]
#  [ 33  31  51 160  35 339 185  99  18  49]
#  [ 56  13  97  34 325  89 208 133  27  18]
#  [ 24  15  75  96  58 429 148 111  26  18]
#  [  7  17  58  73 120 118 532  56   5  14]
#  [ 35  23  44  49 104  95  82 486  23  59]
#  [148  79  12  24   7  68  14  27 522  99]
#  [ 55 166   6  48   3  26  47  87  92 470]]
#
# Classification accuracy for each class:
#
# 0: 0.4610
# 1: 0.4730
# 2: 0.1930
# 3: 0.1600
# 4: 0.3250
# 5: 0.4290
# 6: 0.5320
# 7: 0.4860
# 8: 0.5220
# 9: 0.4700

# %% [markdown]
# In the next notebook, we'll introduce convolutional layers, which are commonly used for images.

# %% [markdown]
# # In-class exercise: improve the accuracy of this model

# %% [markdown]
# How can you improve model accuracy by increasing epochs, stacking more layers, or changing the optimizer?

# %% [markdown]
# **Solution:**
#
# In order to improve the accuracy of this model, I tried few things: I changed the hidden units in the model, I changed the optimizer to Adam, and maintained the number of epochs, Then with these, I obtained an accuracy rate of 49.1% on the test data.
#
# The codes are shown below.

# %%
class NonlinearClassifier2(tf.keras.models.Model):

    def __init__(self, activation=tf.nn.tanh):
        tf.keras.models.Model.__init__(self)

        self.layer_1 = tf.keras.layers.Dense(150, activation='relu')
        
        # A bit more complex model: (need to uncomment in call fn as well)
        self.layer_2 = tf.keras.layers.Dense(100, activation='relu')
        self.drop_3 = tf.keras.layers.Dropout(0.2)
        self.layer_4 = tf.keras.layers.Dense(50, activation='relu')
        self.drop_5 = tf.keras.layers.Dropout(0.2)

        # The last layer needs to be like this:
        self.layer_out = tf.keras.layers.Dense(10, activation='softmax')


    def call(self, inputs):

        x = tf.keras.layers.Flatten()(inputs)
        x = self.layer_1(x)
        
        # The more complex version:
        x = self.layer_2(x)
        x = self.drop_3(x)
        x = self.layer_4(x)
        x = self.drop_5(x)
        
        x = self.layer_out(x)

        return x

# %%
nonlinear_model2 = NonlinearClassifier2()

nonlinear_model2.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=['accuracy'])

# %%
batch_size = 512
epochs = 30
history = nonlinear_model2.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=2)
# Out:
# Epoch 1/30
# 98/98 - 3s - loss: 2.0840 - accuracy: 0.2273 - 3s/epoch - 34ms/step
# Epoch 2/30
# 98/98 - 3s - loss: 1.8844 - accuracy: 0.3204 - 3s/epoch - 28ms/step
# Epoch 3/30
# 98/98 - 3s - loss: 1.8077 - accuracy: 0.3485 - 3s/epoch - 28ms/step
# Epoch 4/30
# 98/98 - 3s - loss: 1.7506 - accuracy: 0.3753 - 3s/epoch - 33ms/step
# Epoch 5/30
# 98/98 - 3s - loss: 1.7124 - accuracy: 0.3895 - 3s/epoch - 28ms/step
# Epoch 6/30
# 98/98 - 3s - loss: 1.6612 - accuracy: 0.4104 - 3s/epoch - 28ms/step
# Epoch 7/30
# 98/98 - 3s - loss: 1.6380 - accuracy: 0.4141 - 3s/epoch - 29ms/step
# Epoch 8/30
# 98/98 - 3s - loss: 1.6145 - accuracy: 0.4239 - 3s/epoch - 28ms/step
# Epoch 9/30
# 98/98 - 3s - loss: 1.6001 - accuracy: 0.4324 - 3s/epoch - 29ms/step
# Epoch 10/30
# 98/98 - 3s - loss: 1.5791 - accuracy: 0.4380 - 3s/epoch - 28ms/step
# Epoch 11/30
# 98/98 - 3s - loss: 1.5620 - accuracy: 0.4456 - 3s/epoch - 29ms/step
# Epoch 12/30
# 98/98 - 3s - loss: 1.5484 - accuracy: 0.4474 - 3s/epoch - 28ms/step
# Epoch 13/30
# 98/98 - 3s - loss: 1.5348 - accuracy: 0.4544 - 3s/epoch - 28ms/step
# Epoch 14/30
# 98/98 - 3s - loss: 1.5154 - accuracy: 0.4609 - 3s/epoch - 28ms/step
# Epoch 15/30
# 98/98 - 3s - loss: 1.5156 - accuracy: 0.4614 - 3s/epoch - 28ms/step
# Epoch 16/30
# 98/98 - 3s - loss: 1.4974 - accuracy: 0.4697 - 3s/epoch - 28ms/step
# Epoch 17/30
# 98/98 - 3s - loss: 1.4925 - accuracy: 0.4668 - 3s/epoch - 28ms/step
# Epoch 18/30
# 98/98 - 3s - loss: 1.4801 - accuracy: 0.4726 - 3s/epoch - 29ms/step
# Epoch 19/30
# 98/98 - 3s - loss: 1.4733 - accuracy: 0.4769 - 3s/epoch - 28ms/step
# Epoch 20/30
# 98/98 - 3s - loss: 1.4620 - accuracy: 0.4797 - 3s/epoch - 28ms/step
# Epoch 21/30
# 98/98 - 3s - loss: 1.4589 - accuracy: 0.4797 - 3s/epoch - 28ms/step
# Epoch 22/30
# 98/98 - 3s - loss: 1.4421 - accuracy: 0.4860 - 3s/epoch - 28ms/step
# Epoch 23/30
# 98/98 - 3s - loss: 1.4430 - accuracy: 0.4855 - 3s/epoch - 28ms/step
# Epoch 24/30
# 98/98 - 3s - loss: 1.4324 - accuracy: 0.4884 - 3s/epoch - 28ms/step
# Epoch 25/30
# 98/98 - 3s - loss: 1.4317 - accuracy: 0.4871 - 3s/epoch - 28ms/step
# Epoch 26/30
# 98/98 - 3s - loss: 1.4179 - accuracy: 0.4943 - 3s/epoch - 28ms/step
# Epoch 27/30
# 98/98 - 4s - loss: 1.4088 - accuracy: 0.4979 - 4s/epoch - 37ms/step
# Epoch 28/30
# 98/98 - 3s - loss: 1.4056 - accuracy: 0.4983 - 3s/epoch - 28ms/step
# Epoch 29/30
# 98/98 - 4s - loss: 1.3966 - accuracy: 0.5019 - 4s/epoch - 42ms/step
# Epoch 30/30
# 98/98 - 3s - loss: 1.3968 - accuracy: 0.5000 - 3s/epoch - 28ms/step

# %%
plt.figure(figsize=(5,3))
plt.plot(history.epoch,history.history['loss'])
plt.title('loss')

plt.figure(figsize=(5,3))
plt.plot(history.epoch,history.history['accuracy'])
plt.title('accuracy');

# %%
# %%time
scores1 = nonlinear_model2.evaluate(x_test, y_test, verbose=2)
print("%s: %.2f%%" % (nonlinear_model2.metrics_names[1], scores1[1]*100))
# Out:
# 313/313 - 1s - loss: 1.4118 - accuracy: 0.4981 - 904ms/epoch - 3ms/step
# accuracy: 49.81%
# CPU times: user 1.18 s, sys: 58.6 ms, total: 1.24 s
# Wall time: 951 ms

# %% [markdown]
# Next, I stacked up more layers in the model, used Adam optimizer and increased the epoch to 100. With these, I obtained accuracy rate of 51.8% on the test data.

# %%
class NonlinearClassifier3(tf.keras.models.Model):

    def __init__(self, activation=tf.nn.tanh):
        tf.keras.models.Model.__init__(self)

        self.layer_1 = tf.keras.layers.Dense(300, activation='relu')
        
        # A bit more complex model: (need to uncomment in call fn as well)
        self.layer_2 = tf.keras.layers.Dense(200, activation='relu')
        self.drop_3 = tf.keras.layers.Dropout(0.2)
        self.layer_4 = tf.keras.layers.Dense(100, activation='relu')
        self.drop_5 = tf.keras.layers.Dropout(0.2)
        self.layer_6 = tf.keras.layers.Dense(50, activation='relu')
        self.drop_7 = tf.keras.layers.Dropout(0.2)


        # The last layer needs to be like this:
        self.layer_out = tf.keras.layers.Dense(10, activation='softmax')


    def call(self, inputs):

        x = tf.keras.layers.Flatten()(inputs)
        x = self.layer_1(x)
        
        # The more complex version:
        x = self.layer_2(x)
        x = self.drop_3(x)
        x = self.layer_4(x)
        x = self.drop_5(x)
        x = self.layer_6(x)
        x = self.drop_7(x)
        
        x = self.layer_out(x)

        return x

# %%
nonlinear_model3 = NonlinearClassifier3()

nonlinear_model3.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=['accuracy'])

# %%
batch_size = 512
epochs = 100
history = nonlinear_model3.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=2)
# Out:
# Epoch 1/100
# 98/98 - 6s - loss: 2.1427 - accuracy: 0.1918 - 6s/epoch - 57ms/step
# Epoch 2/100
# 98/98 - 5s - loss: 1.9103 - accuracy: 0.3040 - 5s/epoch - 51ms/step
# Epoch 3/100
# 98/98 - 5s - loss: 1.8122 - accuracy: 0.3466 - 5s/epoch - 51ms/step
# Epoch 4/100
# 98/98 - 5s - loss: 1.7471 - accuracy: 0.3729 - 5s/epoch - 51ms/step
# Epoch 5/100
# 98/98 - 5s - loss: 1.6917 - accuracy: 0.3952 - 5s/epoch - 51ms/step
# Epoch 6/100
# 98/98 - 7s - loss: 1.6522 - accuracy: 0.4119 - 7s/epoch - 69ms/step
# Epoch 7/100
# 98/98 - 8s - loss: 1.6123 - accuracy: 0.4264 - 8s/epoch - 77ms/step
# Epoch 8/100
# 98/98 - 5s - loss: 1.5826 - accuracy: 0.4349 - 5s/epoch - 51ms/step
# Epoch 9/100
# 98/98 - 6s - loss: 1.5567 - accuracy: 0.4450 - 6s/epoch - 57ms/step
# Epoch 10/100
# 98/98 - 5s - loss: 1.5427 - accuracy: 0.4491 - 5s/epoch - 51ms/step
# Epoch 11/100
# 98/98 - 5s - loss: 1.5242 - accuracy: 0.4580 - 5s/epoch - 51ms/step
# Epoch 12/100
# 98/98 - 5s - loss: 1.4953 - accuracy: 0.4688 - 5s/epoch - 51ms/step
# Epoch 13/100
# 98/98 - 5s - loss: 1.4863 - accuracy: 0.4699 - 5s/epoch - 52ms/step
# Epoch 14/100
# 98/98 - 5s - loss: 1.4654 - accuracy: 0.4779 - 5s/epoch - 51ms/step
# Epoch 15/100
# 98/98 - 5s - loss: 1.4449 - accuracy: 0.4871 - 5s/epoch - 56ms/step
# Epoch 16/100
# 98/98 - 5s - loss: 1.4401 - accuracy: 0.4911 - 5s/epoch - 51ms/step
# Epoch 17/100
# 98/98 - 5s - loss: 1.4346 - accuracy: 0.4902 - 5s/epoch - 51ms/step
# Epoch 18/100
# 98/98 - 5s - loss: 1.4178 - accuracy: 0.4947 - 5s/epoch - 51ms/step
# Epoch 19/100
# 98/98 - 5s - loss: 1.4001 - accuracy: 0.5016 - 5s/epoch - 51ms/step
# Epoch 20/100
# 98/98 - 5s - loss: 1.3915 - accuracy: 0.5030 - 5s/epoch - 51ms/step
# Epoch 21/100
# 98/98 - 5s - loss: 1.3792 - accuracy: 0.5067 - 5s/epoch - 51ms/step
# Epoch 22/100
# 98/98 - 5s - loss: 1.3796 - accuracy: 0.5100 - 5s/epoch - 51ms/step
# Epoch 23/100
# 98/98 - 5s - loss: 1.3610 - accuracy: 0.5158 - 5s/epoch - 51ms/step
# Epoch 24/100
# 98/98 - 5s - loss: 1.3524 - accuracy: 0.5172 - 5s/epoch - 51ms/step
# Epoch 25/100
# 98/98 - 5s - loss: 1.3448 - accuracy: 0.5243 - 5s/epoch - 51ms/step
# Epoch 26/100
# 98/98 - 5s - loss: 1.3392 - accuracy: 0.5222 - 5s/epoch - 51ms/step
# Epoch 27/100
# 98/98 - 7s - loss: 1.3290 - accuracy: 0.5260 - 7s/epoch - 69ms/step
# Epoch 28/100
# 98/98 - 5s - loss: 1.3157 - accuracy: 0.5309 - 5s/epoch - 51ms/step
# Epoch 29/100
# 98/98 - 5s - loss: 1.3105 - accuracy: 0.5331 - 5s/epoch - 51ms/step
# Epoch 30/100
# 98/98 - 5s - loss: 1.3091 - accuracy: 0.5357 - 5s/epoch - 51ms/step
# Epoch 31/100
# 98/98 - 5s - loss: 1.3005 - accuracy: 0.5375 - 5s/epoch - 51ms/step
# Epoch 32/100
# 98/98 - 5s - loss: 1.2868 - accuracy: 0.5425 - 5s/epoch - 51ms/step
# Epoch 33/100
# 98/98 - 5s - loss: 1.2876 - accuracy: 0.5432 - 5s/epoch - 56ms/step
# Epoch 34/100
# 98/98 - 5s - loss: 1.2706 - accuracy: 0.5470 - 5s/epoch - 51ms/step
# Epoch 35/100
# 98/98 - 5s - loss: 1.2752 - accuracy: 0.5431 - 5s/epoch - 51ms/step
# Epoch 36/100
# 98/98 - 5s - loss: 1.2552 - accuracy: 0.5504 - 5s/epoch - 51ms/step
# Epoch 37/100
# 98/98 - 5s - loss: 1.2532 - accuracy: 0.5530 - 5s/epoch - 51ms/step
# Epoch 38/100
# 98/98 - 5s - loss: 1.2581 - accuracy: 0.5534 - 5s/epoch - 51ms/step
# Epoch 39/100
# 98/98 - 5s - loss: 1.2433 - accuracy: 0.5596 - 5s/epoch - 51ms/step
# Epoch 40/100
# 98/98 - 5s - loss: 1.2254 - accuracy: 0.5644 - 5s/epoch - 51ms/step
# Epoch 41/100
# 98/98 - 5s - loss: 1.2336 - accuracy: 0.5597 - 5s/epoch - 51ms/step
# Epoch 42/100
# 98/98 - 5s - loss: 1.2278 - accuracy: 0.5647 - 5s/epoch - 51ms/step
# Epoch 43/100
# 98/98 - 5s - loss: 1.2197 - accuracy: 0.5663 - 5s/epoch - 51ms/step
# Epoch 44/100
# 98/98 - 5s - loss: 1.2089 - accuracy: 0.5688 - 5s/epoch - 51ms/step
# Epoch 45/100
# 98/98 - 5s - loss: 1.1976 - accuracy: 0.5745 - 5s/epoch - 51ms/step
# Epoch 46/100
# 98/98 - 5s - loss: 1.1973 - accuracy: 0.5739 - 5s/epoch - 55ms/step
# Epoch 47/100
# 98/98 - 5s - loss: 1.1910 - accuracy: 0.5752 - 5s/epoch - 51ms/step
# Epoch 48/100
# 98/98 - 5s - loss: 1.1879 - accuracy: 0.5769 - 5s/epoch - 51ms/step
# Epoch 49/100
# 98/98 - 5s - loss: 1.1800 - accuracy: 0.5780 - 5s/epoch - 51ms/step
# Epoch 50/100
# 98/98 - 5s - loss: 1.1905 - accuracy: 0.5758 - 5s/epoch - 51ms/step
# Epoch 51/100
# 98/98 - 5s - loss: 1.1771 - accuracy: 0.5798 - 5s/epoch - 51ms/step
# Epoch 52/100
# 98/98 - 5s - loss: 1.1835 - accuracy: 0.5785 - 5s/epoch - 51ms/step
# Epoch 53/100
# 98/98 - 5s - loss: 1.1714 - accuracy: 0.5838 - 5s/epoch - 51ms/step
# Epoch 54/100
# 98/98 - 5s - loss: 1.1626 - accuracy: 0.5855 - 5s/epoch - 51ms/step
# Epoch 55/100
# 98/98 - 5s - loss: 1.1598 - accuracy: 0.5856 - 5s/epoch - 51ms/step
# Epoch 56/100
# 98/98 - 5s - loss: 1.1570 - accuracy: 0.5882 - 5s/epoch - 51ms/step
# Epoch 57/100
# 98/98 - 6s - loss: 1.1483 - accuracy: 0.5916 - 6s/epoch - 65ms/step
# Epoch 58/100
# 98/98 - 5s - loss: 1.1463 - accuracy: 0.5922 - 5s/epoch - 51ms/step
# Epoch 59/100
# 98/98 - 5s - loss: 1.1435 - accuracy: 0.5910 - 5s/epoch - 51ms/step
# Epoch 60/100
# 98/98 - 5s - loss: 1.1460 - accuracy: 0.5924 - 5s/epoch - 51ms/step
# Epoch 61/100
# 98/98 - 5s - loss: 1.1427 - accuracy: 0.5913 - 5s/epoch - 51ms/step
# Epoch 62/100
# 98/98 - 5s - loss: 1.1268 - accuracy: 0.5991 - 5s/epoch - 51ms/step
# Epoch 63/100
# 98/98 - 5s - loss: 1.1329 - accuracy: 0.5947 - 5s/epoch - 51ms/step
# Epoch 64/100
# 98/98 - 5s - loss: 1.1250 - accuracy: 0.5961 - 5s/epoch - 51ms/step
# Epoch 65/100
# 98/98 - 5s - loss: 1.1191 - accuracy: 0.6009 - 5s/epoch - 51ms/step
# Epoch 66/100
# 98/98 - 5s - loss: 1.1117 - accuracy: 0.6036 - 5s/epoch - 51ms/step
# Epoch 67/100
# 98/98 - 5s - loss: 1.1204 - accuracy: 0.5999 - 5s/epoch - 51ms/step
# Epoch 68/100
# 98/98 - 5s - loss: 1.1157 - accuracy: 0.6010 - 5s/epoch - 51ms/step
# Epoch 69/100
# 98/98 - 5s - loss: 1.1031 - accuracy: 0.6072 - 5s/epoch - 51ms/step
# Epoch 70/100
# 98/98 - 5s - loss: 1.1070 - accuracy: 0.6051 - 5s/epoch - 51ms/step
# Epoch 71/100
# 98/98 - 5s - loss: 1.1106 - accuracy: 0.6013 - 5s/epoch - 51ms/step
# Epoch 72/100
# 98/98 - 5s - loss: 1.1036 - accuracy: 0.6040 - 5s/epoch - 51ms/step
# Epoch 73/100
# 98/98 - 5s - loss: 1.0916 - accuracy: 0.6089 - 5s/epoch - 51ms/step
# Epoch 74/100
# 98/98 - 5s - loss: 1.0872 - accuracy: 0.6126 - 5s/epoch - 51ms/step
# Epoch 75/100
# 98/98 - 5s - loss: 1.0825 - accuracy: 0.6129 - 5s/epoch - 51ms/step
# Epoch 76/100
# 98/98 - 5s - loss: 1.0852 - accuracy: 0.6117 - 5s/epoch - 51ms/step
# Epoch 77/100
# 98/98 - 5s - loss: 1.0710 - accuracy: 0.6179 - 5s/epoch - 51ms/step
# Epoch 78/100
# 98/98 - 5s - loss: 1.0726 - accuracy: 0.6156 - 5s/epoch - 51ms/step
# Epoch 79/100
# 98/98 - 5s - loss: 1.0742 - accuracy: 0.6158 - 5s/epoch - 51ms/step
# Epoch 80/100
# 98/98 - 5s - loss: 1.0811 - accuracy: 0.6139 - 5s/epoch - 51ms/step
# Epoch 81/100
# 98/98 - 5s - loss: 1.0681 - accuracy: 0.6174 - 5s/epoch - 51ms/step
# Epoch 82/100
# 98/98 - 5s - loss: 1.0580 - accuracy: 0.6207 - 5s/epoch - 51ms/step
# Epoch 83/100
# 98/98 - 5s - loss: 1.0618 - accuracy: 0.6191 - 5s/epoch - 51ms/step
# Epoch 84/100
# 98/98 - 5s - loss: 1.0667 - accuracy: 0.6178 - 5s/epoch - 51ms/step
# Epoch 85/100
# 98/98 - 5s - loss: 1.0546 - accuracy: 0.6221 - 5s/epoch - 51ms/step
# Epoch 86/100
# 98/98 - 5s - loss: 1.0653 - accuracy: 0.6193 - 5s/epoch - 51ms/step
# Epoch 87/100
# 98/98 - 5s - loss: 1.0624 - accuracy: 0.6187 - 5s/epoch - 51ms/step
# Epoch 88/100
# 98/98 - 6s - loss: 1.0485 - accuracy: 0.6260 - 6s/epoch - 64ms/step
# Epoch 89/100
# 98/98 - 5s - loss: 1.0540 - accuracy: 0.6227 - 5s/epoch - 51ms/step
# Epoch 90/100
# 98/98 - 5s - loss: 1.0441 - accuracy: 0.6265 - 5s/epoch - 51ms/step
# Epoch 91/100
# 98/98 - 5s - loss: 1.0442 - accuracy: 0.6255 - 5s/epoch - 51ms/step
# Epoch 92/100
# 98/98 - 5s - loss: 1.0455 - accuracy: 0.6268 - 5s/epoch - 51ms/step
# Epoch 93/100
# 98/98 - 5s - loss: 1.0468 - accuracy: 0.6259 - 5s/epoch - 51ms/step
# Epoch 94/100
# 98/98 - 5s - loss: 1.0431 - accuracy: 0.6276 - 5s/epoch - 51ms/step
# Epoch 95/100
# 98/98 - 5s - loss: 1.0340 - accuracy: 0.6306 - 5s/epoch - 51ms/step
# Epoch 96/100
# 98/98 - 5s - loss: 1.0298 - accuracy: 0.6292 - 5s/epoch - 51ms/step
# Epoch 97/100
# 98/98 - 5s - loss: 1.0321 - accuracy: 0.6303 - 5s/epoch - 51ms/step
# Epoch 98/100
# 98/98 - 5s - loss: 1.0373 - accuracy: 0.6260 - 5s/epoch - 51ms/step
# Epoch 99/100
# 98/98 - 5s - loss: 1.0304 - accuracy: 0.6298 - 5s/epoch - 51ms/step
# Epoch 100/100
# 98/98 - 5s - loss: 1.0251 - accuracy: 0.6315 - 5s/epoch - 51ms/step

# %%
plt.figure(figsize=(5,3))
plt.plot(history.epoch,history.history['loss'])
plt.title('loss')

plt.figure(figsize=(5,3))
plt.plot(history.epoch,history.history['accuracy'])
plt.title('accuracy');

# %%
# %%time
scores1 = nonlinear_model3.evaluate(x_test, y_test, verbose=2)
print("%s: %.2f%%" % (nonlinear_model3.metrics_names[1], scores1[1]*100))
# Out:
# 313/313 - 1s - loss: 1.4331 - accuracy: 0.5183 - 1s/epoch - 4ms/step
# accuracy: 51.83%
# CPU times: user 1.95 s, sys: 71.4 ms, total: 2.02 s
# Wall time: 1.38 s
